# %% [markdown]
# <a href="https://colab.research.google.com/github/Erickdejesuslima/aulas-de-python-ADS/blob/master/Lista%205%20de%20probabilidade%20e%20estat%C3%ADstica%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Disciplina Probabilidade e Estatística

#Aluno: Erick de Jesus Lima (20114290128)

#Lista 5

#questão 1

import statistics 

consumo = [10, 13, 17, 9, 8, 11, 13, 7]

# letra A) média simples
'''
print(statistics.mean(consumo)) 
'''
# letra B) média harmônica
'''
print(statistics.harmonic_mean(consumo))  
'''
# letra C) média geométrica 
'''
from scipy.stats.mstats import gmean
media = gmean([10, 13, 17, 9, 8, 11, 13, 7])
print(media)
'''
# letra D) Moda
'''
print(statistics.mode(consumo))
'''

# letra E) Variância
'''
print(statistics.variance(consumo))
'''

# letra F) Desvio padrão
'''
print(statistics.stdev(consumo))
'''
#-------------------------------------------------------------------------------
# Questão 2

escala = [67, 75, 63, 72, 77, 78, 81, 77, 80]

# letra A) média simples, harmônica e geométrica
'''
print(statistics.mean(escala))

print(statistics.harmonic_mean(escala))

from scipy.stats.mstats import gmean
escala = gmean([10, 13, 17, 9, 8, 11, 13, 7])
print(escala)
'''
# letra B) Moda
'''
print(statistics.mode(escala))
'''
# letra C) Mediana
'''
print(statistics.median(escala))
'''
# letra D) Variância
'''
print(statistics.variance(escala))
'''
# letra E) Desvio padrão
'''
print(statistics.stdev(escala))
'''
#-------------------------------------------------------------------------------

# Questão 3 
'''
x = [4.0, 4.5, 5.0, 5.0, 5.0, 5.5, 6.0, 6.0, 6.5, 6.5, 6.5, 6.5, 7.0, 7.0, 7.0, 7.0, 7.0, 7.0, 7.5, 8.5, 9.0, 9.0, 9.0, 9.5, 10.0, 10.0, 10.5, 10.5, 11.0, 12.0, 12.5, 13.0, 13.0 ]

coeficiente_variacao = (statistics.stdev(x)/statistics.mean(x))*100

print(coeficiente_variacao)
'''

#-------------------------------------------------------------------------------
# Questão 4
'''
cafe = [12, 15, 18, 22, 17, 14, 18, 23, 29, 12]

# letra A) média

print(statistics.mean(cafe))

# letra B) mediana 

print(statistics.median(cafe))

# letra C) desvio padrão 

print(statistics.stdev(cafe))
'''

#-------------------------------------------------------------------------------
# Questão 5
'''
from scipy.stats.mstats import gmean
nota = 0
lista = []

while nota != (-999):

  nota = float(input('Digita a nota: '))

  if (nota >= 0 and nota <= 10):
    print('entrou')
    lista.append(nota)
    print(lista)
  else:
    print('Erro')
else:
  print("A média aritimética simples é:", statistics.mean(lista),"A média harmônica é", statistics.harmonic_mean(lista),"A média geométrica é", gmean(lista), "A moda é: ", statistics.mode(lista), "a variância é ", statistics.variance(lista), "o desvio padrão é: ", statistics.stdev(lista), "o coeficiente de variância é: ", statistics.stdev(x)/statistics.mean(x)*100 )
'''
#-------------------------------------------------------------------------------
# Questão 6
'''
nota1 = float(input("digite o valor da nota 1: "))
nota2 = float(input("digite o valor da nota 2: "))
nota3 = float(input("digite o valor da nota 3: "))
if nota1 <0 or nota1 >10:
  print("invalido")

elif nota2 <0 or nota2 >10:
  print("invalido")

elif nota3 <0 or nota3 >10:
  print("invalido")

else:
  print((nota1*3+nota2*4+nota3*3)/3+4+3)  

 '''
