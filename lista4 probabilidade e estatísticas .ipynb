# %% [markdown]
# <a href="https://colab.research.google.com/github/Erickdejesuslima/aulas-de-python-ADS/blob/master/lista4%20probabilidade%20e%20estat%C3%ADsticas%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Disciplina Probabilidade e Estatística

#Aluno: Erick de Jesus Lima

#Lista 4

#questão 1
'''lados = int(input("Insira o número de lados: "))

if lados == 3:
    medida = input("insira a medida dos lados em cm: ") #cálculo da média
    area =(lados ** 2 * 3 ** (1/2))/4 # cálculo da área 
    print("TRIÂNGULO e a área é de: ", area, "cm²" )

elif lados == 4:
    medida = input("insira a medida dos lados em cm: ") #cálculo da média
    area =(lados ** 2)  # calculo da área 
    print("QUADRADO e a área é de: ", area, "cm²" )
    

elif lados == 5:
  print("PENTÁGONO")
#----------------//----------------------------------------
#questão 2

elif lados < 3: 
   print("NÃO É UM POLÍGONO")

else:
  print("POLÍGONO NÃO IDENTIFICADO")'''

#-------------------------------//--------------------------
#questão 3

'''numero1 = int(input("insira o valor do 1º número: "))

numero2 = int(input("insira o valor do 2º número: "))

numero3 = int(input("insira o valor do 3º número: "))

if numero1 > numero2 and numero1 >  numero3:
  print("O maior número é o ",numero1)

elif numero2 > numero1 and numero2 > numero3:
  print("O maior número é o ",numero2)

elif  numero3 >  numero1 and numero3 > numero2:
  print("O maior número é o ",numero3)

else:
  print("Não pode haver números repetidos")'''

#---------------------------------------------------//-----------------
#questão 4
'''
lado1 = float(input("insira a medida do lado direito em cm: "))
lado2 = float(input("insira a medida do lado esquerdo em cm: "))
lado3 = float(input("insira a medida da base em cm: "))

if lado1 == lado2 and lado2 == lado3 and lado1 == lado3: 
  print("Equilátero")

elif lado1 == lado2 or lado2 == lado3 or lado1 == lado3: 
  print("Isóscele")

elif lado1 != lado2 and lado2 != lado3 and lado1 != lado3: 
  print("Escaleno")'''

#-----------------------------------------------//--------------------
#questão 5
'''
angulo1 = int(input("insira o valor do 1º ângulo: "))

angulo2 = int(input("insira o valor do 2º ângulo: "))

angulo3 = int(input("insira o valor do 3º ângulo: "))

if angulo1 == 90 and angulo2 == 90 and angulo3 == 90:
  print("trinângulo retangulo ")

elif angulo1 > 90 and angulo2 > 90 and angulo3 > 90:
  print("Triângulo Obtusângulo")

elif angulo1 < 90 and angulo2 < 90 and angulo3 < 90:
  print("Triângulo Acutângulo")'''


#-----------------------------------------------//--------------------
#questão 6
'''
num1 = int(input('Entre com um número: '))
for lista in range(num1):
    print(lista)'''
    
#------------------------------------------ //------------------------
#questão 7
''' 
numero = int(input("digite um valor entre 1 e 4: "))
while (numero <1 or numero > 4):
  print('entrada invalida: ')
  numero = int(input("Digite um número entre 1 e 4: "))

else: 
  print(numero) '''

#------------------------------------------//----------------------------
#questão 8
'''
numero = int(input('Digite um número: '))
lista = []

while numero != 0:
  lista.append(numero)
  print(max(lista))
  numero = int(input('Digite um número: '))
else:
  print('Término do programa')'''

#-------------------------------------------//--------------------------
#questão 9
'''
numero = int(input('Digite um número: '))
u = numero // 1 % 10 #unidade
d = numero // 10 % 10 #dezena
c = numero // 100 % 10 #centena
m = numero // 1000 % 10 #milhar
print('Milhar:', m)
print('Centena:', d)
print('Dezena:', c)
print('Unidade:', u)
'''
